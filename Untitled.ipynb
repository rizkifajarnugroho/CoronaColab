# %% [markdown]
# Bayesian Modelling for Growth Prediction

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('data.csv')

# %%
data.head()
# Out:
#   Province/State Country/Region      Lat      Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN       Thailand  15.0000  101.0000        2        3        5
# 1            NaN          Japan  36.0000  138.0000        2        1        2
# 2            NaN      Singapore   1.2833  103.8333        0        1        3
# 3            NaN          Nepal  28.1667   84.2500        0        0        0
# 4            NaN       Malaysia   2.5000  112.5000        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  3/5/20  3/6/20  3/7/20  3/8/20  3/9/20  \
# 0        7        8        8  ...      47      48      50      50      50
# 1        2        4        4  ...     360     420     461     502     511
# 2        3        4        5  ...     117     130     138     150     150
# 3        1        1        1  ...       1       1       1       1       1
# 4        3        4        4  ...      50      83      93      99     117
#
#    3/10/20  3/11/20  3/12/20  3/13/20  3/14/20
# ...

# %%
#data['type'] = name.lower()
data.columns.name = 'date'

# %%
data.head()
# Out:
# date Province/State Country/Region      Lat      Long  1/22/20  1/23/20  \
# 0               NaN       Thailand  15.0000  101.0000        2        3
# 1               NaN          Japan  36.0000  138.0000        2        1
# 2               NaN      Singapore   1.2833  103.8333        0        1
# 3               NaN          Nepal  28.1667   84.2500        0        0
# 4               NaN       Malaysia   2.5000  112.5000        0        0
#
# date  1/24/20  1/25/20  1/26/20  1/27/20  ...  3/5/20  3/6/20  3/7/20  3/8/20  \
# 0           5        7        8        8  ...      47      48      50      50
# 1           2        2        4        4  ...     360     420     461     502
# 2           3        3        4        5  ...     117     130     138     150
# 3           0        1        1        1  ...       1       1       1       1
# 4           0        3        4        4  ...      50      83      93      99
#
# date  3/9/20  3/10/20  3/11/20  3/12/20  3/13/20  3/14/20
# ...

# %%
data = (data.set_index('type', append=True).reset_index(['Lat', 'Long'], drop=True).stack().reset_index().set_index('date'))
data.index = pd.to_datetime(data.index)
data.columns = ['country', 'state', 'type', 'cases']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Rizki\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'type'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-7594fa4eb1d9> in <module>
# ...
